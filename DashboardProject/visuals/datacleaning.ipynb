# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# load file
df = pd.read_csv('../../data/raw/pollution_2000_2021.csv')
df.describe()
# Out:
#                 Year          Month            Day        O3 Mean  \
# count  608699.000000  608699.000000  608699.000000  608699.000000
# mean     2011.040529       6.508670      15.737176       0.028477
# std         6.122558       3.310633       8.806949       0.012218
# min      2000.000000       1.000000       1.000000      -0.000706
# 25%      2006.000000       4.000000       8.000000       0.019647
# 50%      2012.000000       7.000000      16.000000       0.028235
# 75%      2016.000000       9.000000      23.000000       0.036765
# max      2021.000000      12.000000      31.000000       0.107353
#
#        O3 1st Max Value  O3 1st Max Hour         O3 AQI        CO Mean  \
# count     608699.000000    608699.000000  608699.000000  608699.000000
# mean           0.038903        10.773469      39.112517       0.337258
# std            0.015031         3.308152      22.480864       0.282958
# min            0.000000         7.000000       0.000000      -0.437500
# ...

# %%
df.describe(exclude='number')
# Out:
#               Date                       Address       State       County  \
# count       608699                        608699      608699       608699
# unique        7975                           216          48          136
# top     2019-12-04  5888 MISSION BLVD., RUBIDOUX  California  Los Angeles
# freq           104                         12867      187403        30891
#
#                  City
# count          608699
# unique            148
# top     Not in a city
# freq            50716

# %%
df1 = df.drop(columns=['O3 1st Max Value', 'O3 1st Max Hour', 'CO 1st Max Value', 'CO 1st Max Hour', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'NO2 1st Max Value', 'NO2 1st Max Hour'])
df1.head()
# Out:
#          Date  Year  Month  Day                                  Address  \
# 0  2000-01-01  2000      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1  2000-01-02  2000      1    2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 2  2000-01-03  2000      1    3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 3  2000-01-04  2000      1    4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 4  2000-01-05  2000      1    5  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
#
#      State    County     City   O3 Mean  O3 AQI   CO Mean  CO AQI  SO2 Mean  \
# 0  Arizona  Maricopa  Phoenix  0.019765      37  0.878947    25.0  3.000000
# 1  Arizona  Maricopa  Phoenix  0.015882      30  1.066667    26.0  1.958333
# 2  Arizona  Maricopa  Phoenix  0.009353      15  1.762500    28.0  5.250000
# 3  Arizona  Maricopa  Phoenix  0.015882      31  1.829167    34.0  7.083333
# 4  Arizona  Maricopa  Phoenix  0.007353      11  2.700000    42.0  8.708333
#
#    SO2 AQI   NO2 Mean  NO2 AQI
# 0     13.0  19.041667       46
# ...

# %%
df1.to_csv('../../data/processed/pollution.csv', index=False)
