# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid",
              font_scale=1.2, # This scales the fonts slightly higher
              )
# And we're going to remove the top and right axis lines
plt.rc("axes.spines", top=False, right=False)

# %%
df = pd.read_csv('../../data/processed/pollution.csv')

df['Total AQI'] = df['O3 AQI'] + df['CO AQI'] + df['SO2 AQI'] + df['NO2 AQI']
df.head()
# Out:
#          Date  Year  Month  Day                                  Address  \
# 0  2000-01-01  2000      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1  2000-01-02  2000      1    2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 2  2000-01-03  2000      1    3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 3  2000-01-04  2000      1    4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 4  2000-01-05  2000      1    5  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
#
#      State    County     City   O3 Mean  O3 AQI   CO Mean  CO AQI  SO2 Mean  \
# 0  Arizona  Maricopa  Phoenix  0.019765      37  0.878947    25.0  3.000000
# 1  Arizona  Maricopa  Phoenix  0.015882      30  1.066667    26.0  1.958333
# 2  Arizona  Maricopa  Phoenix  0.009353      15  1.762500    28.0  5.250000
# 3  Arizona  Maricopa  Phoenix  0.015882      31  1.829167    34.0  7.083333
# 4  Arizona  Maricopa  Phoenix  0.007353      11  2.700000    42.0  8.708333
#
#    SO2 AQI   NO2 Mean  NO2 AQI  Total AQI
# 0     13.0  19.041667       46      121.0
# 1      4.0  22.958333       34       94.0
# 2     16.0  38.125000       48      107.0
# 3     23.0  40.260870       72      160.0
# 4     21.0  48.450000       58      132.0

# %%
city = "Phoenix" #input from user

df_filtered = df[df['City'] == city]
df_filtered.head()
# Out:
#          Date  Year  Month  Day                                  Address  \
# 0  2000-01-01  2000      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1  2000-01-02  2000      1    2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 2  2000-01-03  2000      1    3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 3  2000-01-04  2000      1    4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 4  2000-01-05  2000      1    5  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
#
#      State    County     City   O3 Mean  O3 AQI   CO Mean  CO AQI  SO2 Mean  \
# 0  Arizona  Maricopa  Phoenix  0.019765      37  0.878947    25.0  3.000000
# 1  Arizona  Maricopa  Phoenix  0.015882      30  1.066667    26.0  1.958333
# 2  Arizona  Maricopa  Phoenix  0.009353      15  1.762500    28.0  5.250000
# 3  Arizona  Maricopa  Phoenix  0.015882      31  1.829167    34.0  7.083333
# 4  Arizona  Maricopa  Phoenix  0.007353      11  2.700000    42.0  8.708333
#
#    SO2 AQI   NO2 Mean  NO2 AQI  Total AQI
# 0     13.0  19.041667       46      121.0
# 1      4.0  22.958333       34       94.0
# 2     16.0  38.125000       48      107.0
# 3     23.0  40.260870       72      160.0
# 4     21.0  48.450000       58      132.0

# %%
# Convert the 'date' column to datetime format
df_filtered['Date'] = pd.to_datetime(df_filtered['Date'])

# Filter the DataFrame to keep only rows where the date is '01-01'
newdf_filtered = df_filtered.query("Date.dt.month == 1 and Date.dt.day == 1 and (Year==2000 or Year==2004 or Year==208 or Year==2012 or Year==2016 or Year==2020 or Year==2021)" )
newdf_filtered
# Out:
# /var/folders/v8/c55bn0kn77j9t3szq6f6ssw00000gn/T/ipykernel_50100/2593076928.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Date'] = pd.to_datetime(df_filtered['Date'])
#              Date  Year  Month  Day                                  Address  \
# 0      2000-01-01  2000      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 93762  2004-01-01  2004      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 303873 2012-01-01  2012      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 434203 2016-01-01  2016      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 558173 2020-01-01  2020      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 558526 2020-01-01  2020      1    1                       4530 N 17TH AVENUE
# 589662 2021-01-01  2021      1    1                       4530 N 17TH AVENUE
#
#           State    County     City   O3 Mean  O3 AQI   CO Mean  CO AQI  \
# 0       Arizona  Maricopa  Phoenix  0.019765      37  0.878947    25.0
# 93762   Arizona  Maricopa  Phoenix  0.012824      23  0.752632    18.0
# 303873  Arizona  Maricopa  Phoenix  0.019294      26  1.152632    31.0
# 434203  Arizona  Maricopa  Phoenix  0.016882      26  1.426316    28.0
# 558173  Arizona  Maricopa  Phoenix  0.014471      28  0.657895    16.0
# 558526  Arizona  Maricopa  Phoenix  0.012706      26  0.668421    17.0
# 589662  Arizona  Maricopa  Phoenix  0.017176      33  0.947368    22.0
#
#         SO2 Mean  SO2 AQI   NO2 Mean  NO2 AQI  Total AQI
# 0       3.000000     13.0  19.041667       46      121.0
# 93762   2.875000     13.0  26.291667       46      100.0
# 303873  1.458333      7.0  21.208333       31       95.0
# 434203  2.541667      7.0  29.500000       42      103.0
# 558173  1.125000      3.0  18.083333       32       79.0
# 558526  1.204167      3.0  16.720833       28       74.0
# 589662  2.408333      7.0  23.629167       35       97.0

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(newdf_filtered['Date'], newdf_filtered['Total AQI'], marker='o', linestyle='-')
plt.title('Air Quality Over Time in: '+ city)
plt.xlabel('Date')
plt.ylabel('Air Quality')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
